# %%
import monetio as mio
print(mio.__file__)
# Out:
# /glade/u/home/nmariscal/melodies-monet/monetio/monetio/__init__.py

# %%
# %load_ext autoreload
# %autoreload 2

from melodies_monet import driver
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
an = driver.analysis()

# %%
# an.control = '/glade/u/home/nmariscal/melodies-monet/control_tempo_l2_no2_cesm-se_ben.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/control_tempo_l2_no2_cesm-fv.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/control_tropomi_l2_no2.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/control_tempo_l2_hcho.yaml'

# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/cesm-fv/control_tempo_paired_data_no2.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/cesm-fv/control_tempo_paired_data_hcho.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/control_pandora_no2_cesm-fv.yaml'
# an.control = '/glade/work/emmons/MELODIES/MM_ASIAAQ/control_pandora_musica_no2.yaml'
an.control = '/glade/u/home/nmariscal/melodies-monet/louisa_mm/control_pandora_musica_no2.yaml'

an.read_control()
# an.read_analysis()

# %%
an.open_models()
ds = an.models['cesm_fv'].obj
# Out:
# cesm_fv
# /glade/campaign/acom/acom-weather/emmons/ASIAAQ_sims/f.cam6_3_018mosaic.FCnudged.TS1mosaic.NAEUASne30x8.aaqv3finn.02/regridded_asia_0.1deg/f.cam6_3_018mosaic.FCnudged.TS1mosaic.01x01_3D.aaqv3finn.02.cam.h2.2024-03-20-00000.nc
# **** Reading CESM FV model output...
# > /glade/u/home/nmariscal/melodies-monet/monetio/monetio/models/_cesm_fv_mm.py(43)open_mfdataset()
#      41     """
#      42     import pdb; pdb.set_trace()
# ---> 43     if not surf_only:
#      44         warnings.warn(
#      45             "3D data processing is still experimental in CESM-FV (CAM-Chem), "
# ipdb>  c
# /glade/u/home/nmariscal/melodies-monet/monetio/monetio/models/_cesm_fv_mm.py:43: UserWarning: 3D data processing is still experimental in CESM-FV (CAM-Chem), and has not been properly tested. Use at own risk.
#   if not surf_only:
# /glade/u/home/nmariscal/melodies-monet/monetio/monetio/models/_cesm_fv_mm.py:43: UserWarning: Surface pressure (PS) is not in model keys. Continuing without it.
#   if not surf_only:
# /glade/u/home/nmariscal/melodies-monet/monetio/monetio/models/_cesm_fv_mm.py:43: UserWarning: PHIS is not in model keys. Continuing without it.
#   if not surf_only:

# %%
ds['dz_m'][0, 0, :, :]
# Out:
# <xarray.DataArray 'dz_m' (y: 450, x: 500)> Size: 2MB
# array([[         nan,   2.26149583,  35.74986649, ...,          nan,
#                  nan,  90.57292175],
#        [ 79.81874847, 121.01602936, 130.98687744, ...,          nan,
#                  nan, 116.75662231],
#        [130.98687744, 130.98687744, 130.98687744, ...,  13.32924461,
#                  nan, 125.39070892],
#        ...,
#        [ 50.80308151, 116.93180084, 123.57318115, ..., 119.06574249,
#          95.41559601,   5.66873789],
#        [123.5196228 , 123.51255035, 123.52536011, ..., 119.06574249,
#         119.06574249,   3.31665945],
#        [ 82.78085327,  66.13581848,  49.37773132, ..., 119.06574249,
#         117.10591888,   1.01691151]])
# Coordinates:
#     time       datetime64[ns] 8B 2024-03-20
#     lev        float64 8B 992.6
#     longitude  (y, x) float64 2MB 90.05 90.15 90.25 90.35 ... 139.8 139.9 139.9
#     latitude   (y, x) float64 2MB 0.05 0.05 0.05 0.05 ... 44.95 44.95 44.95
# Dimensions without coordinates: y, x
# Attributes:
#     description:  Layer Thickness (based on midlayer pressure)
#     units:        m

# %%
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:        (time: 8, z: 32, y: 450, x: 500)
# Coordinates:
#   * time           (time) datetime64[ns] 64B 2024-03-20 ... 2024-03-20
#   * lev            (z) float64 256B 992.6 976.3 957.5 ... 14.36 7.595 3.643
#     longitude      (y, x) float64 2MB 90.05 90.15 90.25 ... 139.8 139.9 139.9
#     latitude       (y, x) float64 2MB 0.05 0.05 0.05 0.05 ... 44.95 44.95 44.95
# Dimensions without coordinates: z, y, x
# Data variables:
#     O3             (time, z, y, x) float32 230MB dask.array<chunksize=(1, 16, 225, 250), meta=np.ndarray>
#     NO2            (time, z, y, x) float32 230MB dask.array<chunksize=(1, 16, 225, 250), meta=np.ndarray>
#     dz_m           (time, z, y, x) float64 461MB nan 2.261 ... 5.148e+03 44.58
#     temperature_k  (time, z, y, x) float32 230MB dask.array<chunksize=(1, 16, 225, 250), meta=np.ndarray>
#     alt_msl_m_mid  (time, z, y, x) float32 230MB dask.array<chunksize=(1, 16, 225, 250), meta=np.ndarray>
#     pres_pa_mid    (time, z, y, x) float32 230MB dask.array<chunksize=(1, 16, 225, 250), meta=np.ndarray>
# Attributes: (12/16)
#     Conventions:          CF-1.0
#     source:               CAM
#     case:                 f.cam6_3_018mosaic.FCnudged.TS1mosaic.NAEUASne30x8....
#     logname:              emmons
#     host:                 derecho4
#     initial_file:         /glade/work/emmons/VRM_Files/ne0np4.NAEUAS01.ne30x8...
#     ...                   ...
#     regridded_by:         Regridding_ESMF.py tool using ESMPy (ESMF)
#     regridding_time:      2025-03-04 12:54:03.422773
#     source_file:          /glade/derecho/scratch/emmons/archive/f.cam6_3_018m...
#     source_grid:          /glade/campaign/acom/acom-weather/cdswk/ASIA-AQ/gri...
#     destination_grid:     /glade/campaign/acom/acom-weather/cdswk/ASIA-AQ/gri...
#     regridding_username:  emmons on crhtc56.hpc.ucar.edu

# %%
an.open_obs()
# ds_obs = an.obs['tempo_l2_no2'].obj
# ds_obs = an.obs['tropomi_l2_no2'].obj
# ds_obs = an.obs['tempo_l2_hcho'].obj
ds_obs = an.obs['pandora_no2'].obj
# Out:
# something happened opening file: invalid syntax (read_util.py, line 347)

# %%
# an.open_obs()

# #-- did this in previous step so dont need to do twice
# # ds_obs = an.obs['tempo_l2_no2'].obj
# # ds_obs = an.obs['tropomi_l2_no2'].obj
# # ds_obs = an.obs['tempo_l2_hcho'].obj

# # an.models['cesm_fv'].obj = ds
# an.pair_data()
# an.save_analysis()

# %%
# an.paired['tempo_l2_no2_cesm_fv'].obj
an.paired['tempo_l2_hcho_cesm_fv'].obj
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:          (time: 544, y: 361, x: 571)
# Coordinates:
#   * time             (time) datetime64[ns] 4kB 2024-07-01T00:00:51 ... 2024-0...
#     longitude        (y, x) float64 2MB -127.0 -126.9 -126.8 ... -70.1 -70.0
#     latitude         (y, x) float64 2MB 17.0 17.0 17.0 17.0 ... 53.0 53.0 53.0
# Dimensions without coordinates: y, x
# Data variables:
#     CH2O             (time, y, x) float64 897MB nan nan nan nan ... nan nan nan
#     vertical_column  (time, y, x) float64 897MB nan nan nan nan ... nan nan nan
#     end_time         (time) datetime64[ns] 4kB 2024-07-01T00:34:13.141133 ......
# Attributes:
#     title:
#     format:        NetCDF-4
#     date_created:  2025-04-11
#     dict_json:     {\n    "type": "sat_swath_clm",\n    "radius_of_influence"...
#     group_name:    tempo_l2_hcho_cesm_fv

# %%
an.read_control()
an.plotting()
# Out:
# Warning: vmin_plot and vmax_plot not specified for vertical_column, so default used.
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 2.0, 'markersize': 10.0, 'label': 'tempo_l2_hcho', 'fontsize': 14.4}
# Warning: vmin_plot and vmax_plot not specified for vertical_column, so default used.
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 2.0, 'markersize': 10.0, 'label': 'tempo_l2_hcho', 'fontsize': 14.4}
# Warning: vmin_plot and vmax_plot not specified for vertical_column, so default used.
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 2.0, 'markersize': 10.0, 'label': 'tempo_l2_hcho', 'fontsize': 14.4}
# 0 1e+16
# 0 1e+16
# 0 1e+16
# 0 1e+16
# Warning: ty_scale not specified for vertical_column, so default used.
# Base standard deviation:  2.06e+17
# Reference std: 1
