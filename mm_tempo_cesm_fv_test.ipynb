# %%
import monetio as mio
print(mio.__file__)
# Out:
# /glade/u/home/nmariscal/melodies-monet/monetio/monetio/__init__.py

# %%
# %load_ext autoreload
# %autoreload 2

from melodies_monet import driver

# %%
an = driver.analysis()

# %%
# an.control = '/glade/u/home/nmariscal/melodies-monet/control_tempo_l2_no2_cesm-se_ben.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/control_tempo_l2_no2_cesm-fv.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/control_tropomi_l2_no2.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/control_tempo_l2_hcho.yaml'

# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/cesm-fv/control_tempo_paired_data_no2.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/cesm-fv/control_tempo_paired_data_hcho.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/yaml/control_pandora_no2_cesm-fv.yaml'
# an.control = '/glade/work/emmons/MELODIES/MM_ASIAAQ/control_pandora_musica_no2.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/louisa_mm/control_pandora_musica_no2.yaml'
# an.control = '/glade/u/home/emmons/workdir/MELODIES/MM_ASIAAQ/control_mopitt.yaml'
# an.control = '/glade/u/home/nmariscal/melodies-monet/louisa_mm/control_mopitt.yaml'
an.control = '/glade/u/home/nmariscal/melodies-monet/pair_tempo/yaml/control_tempo_l2_no2_cesm_fv_20240701.yaml'

an.read_control()
# an.read_analysis()

# %%
an.open_models()
ds = an.models['cesm_fv'].obj
# ds = an.models['musica'].obj
# Out:
# cesm_fv
# ['/glade/derecho/scratch/gaubert/tempo/merge/f.e22.FCnudged.ne0CONUSne30x8_ne0CONUSne30x8_mt12.musica_cams_mosaic.003.cam.h1.2024-06-30-03600.nc', '/glade/derecho/scratch/gaubert/tempo/merge/f.e22.FCnudged.ne0CONUSne30x8_ne0CONUSne30x8_mt12.musica_cams_mosaic.003.cam.h1.2024-07-01-03600.nc']
# **** Reading CESM FV model output...
# /glade/u/home/nmariscal/melodies-monet/monetio/monetio/models/_cesm_fv_mm.py:44: UserWarning: 3D data processing is still experimental in CESM-FV (CAM-Chem), and has not been properly tested. Use at own risk.
#   warnings.warn(
# /glade/u/home/nmariscal/melodies-monet/monetio/monetio/models/_cesm_fv_mm.py:274: UserWarning: P0 not in netcdf keys, assuming 100_000 Pa
#   warnings.warn("P0 not in netcdf keys, assuming 100_000 Pa")

# %%
ds['dz_m'][0, 0, :, :]
# Out:
# <xarray.DataArray 'dz_m' (y: 361, x: 571)> Size: 2MB
# array([[129.58259307, 129.59406948, 129.60449289, ..., 131.8600678 ,
#         131.85380792, 131.84786795],
#        [129.55302564, 129.564388  , 129.57515831, ..., 131.85131069,
#         131.84598046, 131.84107705],
#        [129.52423015, 129.53793291, 129.5523828 , ..., 131.84313306,
#         131.83853722, 131.83493927],
#        ...,
#        [125.74892526, 125.84674245, 125.94104961, ..., 124.83370682,
#         124.80309723, 124.76472506],
#        [125.74573403, 125.84830557, 125.94793919, ..., 124.83531109,
#         124.79748013, 124.76029982],
#        [125.78537993, 125.8765918 , 125.96948667, ..., 124.82725934,
#         124.79060983, 124.75456067]])
# Coordinates:
#     time       datetime64[ns] 8B 2024-06-30T01:00:00
#     lev        float64 8B 992.6
#     longitude  (y, x) float64 2MB -127.0 -126.9 -126.8 ... -70.2 -70.1 -70.0
#     latitude   (y, x) float64 2MB 17.0 17.0 17.0 17.0 ... 53.0 53.0 53.0 53.0
# Dimensions without coordinates: y, x
# Attributes:
#     description:  Layer Thickness (based on interface pressure)
#     units:        m

# %%
ds
# Out:
# <xarray.Dataset> Size: 8GB
# Dimensions:        (time: 48, z: 32, y: 361, x: 571)
# Coordinates:
#   * time           (time) datetime64[ns] 384B 2024-06-30T01:00:00 ... 2024-07-02
#   * lev            (z) float64 256B 992.6 976.3 957.5 ... 14.36 7.595 3.643
#     longitude      (y, x) float64 2MB -127.0 -126.9 -126.8 ... -70.2 -70.1 -70.0
#     latitude       (y, x) float64 2MB 17.0 17.0 17.0 17.0 ... 53.0 53.0 53.0
# Dimensions without coordinates: z, y, x
# Data variables:
#     NO2            (time, z, y, x) float32 1GB dask.array<chunksize=(24, 32, 361, 571), meta=np.ndarray>
#     dz_m           (time, z, y, x) float64 3GB 129.6 129.6 ... 6.021e+03
#     temperature_k  (time, z, y, x) float32 1GB dask.array<chunksize=(24, 32, 361, 571), meta=np.ndarray>
#     alt_msl_m_mid  (time, z, y, x) float32 1GB dask.array<chunksize=(24, 32, 361, 571), meta=np.ndarray>
#     pres_pa_mid    (time, z, y, x) float32 1GB dask.array<chunksize=(24, 32, 361, 571), meta=np.ndarray>
# Attributes: (12/21)
#     ne:                         0
#     np:                         4
#     Conventions:                CF-1.0
#     source:                     CAM
#     case:                       f.e22.FCnudged.ne0CONUSne30x8_ne0CONUSne30x8_...
#     logname:                    gaubert
#     ...                         ...
#     source_grid:                ex_dst/ne0CONUS_ne30x8_np4_SCRIP.nc
#     destination_grid:           grids/grid_file_0.1_deg_CONUS.nc
#     regridding_username:        gaubert on crhtc21.hpc.ucar.edu
#     history:                    Tue Apr  1 17:25:27 2025: ncks -A -v time /gl...
#     history_of_appended_files:  Tue Apr  1 17:25:27 2025: Appended file /glad...
#     NCO:                        netCDF Operators version 5.1.9 (Homepage = ht...

# %%
an.open_obs()
ds_obs = an.obs['tempo_l2_no2'].obj
# ds_obs = an.obs['tropomi_l2_no2'].obj
# ds_obs = an.obs['tempo_l2_hcho'].obj
# ds_obs = an.obs['pandora_no2'].obj
# ds_obs = an.obs['mopitt_l3'].obj
# Out:
# Reading TEMPO L2
# /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701*_S*
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T000051Z_S016G02.nc
# /glade/u/home/nmariscal/melodies-monet/monetio/monetio/sat/_tempo_l2_no2_mm.py:66: UserWarning: Calculating pressure in TEMPO data requires surface_pressure. Adding surface_pressure to output variables
#   warnings.warn(
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T000728Z_S016G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T001406Z_S016G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T002043Z_S016G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T002720Z_S016G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T003416Z_S017G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T004056Z_S017G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T004733Z_S017G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T005411Z_S017G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T010048Z_S017G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T010725Z_S017G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T011421Z_S018G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T012101Z_S018G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T012738Z_S018G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T013416Z_S018G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T014053Z_S018G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T014730Z_S018G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T103402Z_S001G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T104042Z_S001G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T104719Z_S001G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T105357Z_S001G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T110034Z_S001G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T110711Z_S001G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T111407Z_S002G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T112047Z_S002G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T112724Z_S002G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T113402Z_S002G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T114039Z_S002G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T114716Z_S002G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T115412Z_S003G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T120052Z_S003G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T120729Z_S003G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T121407Z_S003G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T122044Z_S003G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T122721Z_S003G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T123417Z_S004G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T124057Z_S004G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T124734Z_S004G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T125412Z_S004G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T130049Z_S004G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T130726Z_S004G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T131422Z_S005G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T132102Z_S005G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T132742Z_S005G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T133420Z_S005G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T134057Z_S005G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T134734Z_S005G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T135412Z_S005G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T140049Z_S005G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T140726Z_S005G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T141422Z_S006G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T142102Z_S006G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T142742Z_S006G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T143420Z_S006G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T144057Z_S006G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T144734Z_S006G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T145412Z_S006G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T150049Z_S006G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T150726Z_S006G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T151422Z_S007G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T152102Z_S007G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T152742Z_S007G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T153420Z_S007G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T154057Z_S007G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T154734Z_S007G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T155412Z_S007G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T160049Z_S007G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T160726Z_S007G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T161422Z_S008G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T162102Z_S008G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T162742Z_S008G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T163420Z_S008G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T164057Z_S008G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T164734Z_S008G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T165412Z_S008G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T170049Z_S008G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T170726Z_S008G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T171422Z_S009G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T172102Z_S009G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T172742Z_S009G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T173420Z_S009G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T174057Z_S009G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T174734Z_S009G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T175412Z_S009G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T180049Z_S009G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T180726Z_S009G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T181422Z_S010G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T182102Z_S010G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T182742Z_S010G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T183420Z_S010G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T184057Z_S010G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T184734Z_S010G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T185412Z_S010G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T190049Z_S010G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T190726Z_S010G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T191422Z_S011G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T192102Z_S011G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T192742Z_S011G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T193420Z_S011G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T194057Z_S011G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T194734Z_S011G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T195412Z_S011G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T200049Z_S011G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T200726Z_S011G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T201422Z_S012G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T202102Z_S012G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T202742Z_S012G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T203420Z_S012G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T204057Z_S012G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T204734Z_S012G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T205412Z_S012G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T210049Z_S012G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T210726Z_S012G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T211422Z_S013G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T212102Z_S013G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T212742Z_S013G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T213420Z_S013G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T214057Z_S013G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T214734Z_S013G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T215412Z_S013G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T220049Z_S013G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T220726Z_S013G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T221422Z_S014G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T222102Z_S014G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T222742Z_S014G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T223420Z_S014G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T224057Z_S014G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T224734Z_S014G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T225412Z_S014G07.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T230049Z_S014G08.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T230726Z_S014G09.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T231422Z_S015G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T232102Z_S015G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T232739Z_S015G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T233417Z_S015G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T234054Z_S015G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T234731Z_S015G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240701T235427Z_S016G01.nc

# %%
# an.open_obs()

# #-- did this in previous step so dont need to do twice
# # ds_obs = an.obs['tempo_l2_no2'].obj
# # ds_obs = an.obs['tropomi_l2_no2'].obj
# # ds_obs = an.obs['tempo_l2_hcho'].obj

# # an.models['cesm_fv'].obj = ds
# an.pair_data()
# an.save_analysis()

# %%
an.pair_data()
# Out:
# 1, in pair data
# WARNING: The satellite pairing option apply_ak is being set to True because it was not specified in the YAML. Pairing will fail if there is no AK available.
# Regridding 2024-07-01T00:00:51Z and applying AMF and weights
# Regridding 2024-07-01T00:07:28Z and applying AMF and weights
# Regridding 2024-07-01T00:14:06Z and applying AMF and weights
# Regridding 2024-07-01T00:20:43Z and applying AMF and weights
# Regridding 2024-07-01T00:27:20Z and applying AMF and weights
# Regridding 2024-07-01T00:34:16Z and applying AMF and weights
# Regridding 2024-07-01T00:40:56Z and applying AMF and weights
# Regridding 2024-07-01T00:47:33Z and applying AMF and weights
# Regridding 2024-07-01T00:54:11Z and applying AMF and weights
# Regridding 2024-07-01T01:00:48Z and applying AMF and weights
# Regridding 2024-07-01T01:07:25Z and applying AMF and weights
# Regridding 2024-07-01T01:14:21Z and applying AMF and weights
# Regridding 2024-07-01T01:21:01Z and applying AMF and weights
# Regridding 2024-07-01T01:27:38Z and applying AMF and weights
# Regridding 2024-07-01T01:34:16Z and applying AMF and weights
# Regridding 2024-07-01T01:40:53Z and applying AMF and weights
# Regridding 2024-07-01T01:47:30Z and applying AMF and weights
# Regridding 2024-07-01T10:34:02Z and applying AMF and weights
# Regridding 2024-07-01T10:40:42Z and applying AMF and weights
# Regridding 2024-07-01T10:47:19Z and applying AMF and weights
# Regridding 2024-07-01T10:53:57Z and applying AMF and weights
# Regridding 2024-07-01T11:00:34Z and applying AMF and weights
# Regridding 2024-07-01T11:07:11Z and applying AMF and weights
# Regridding 2024-07-01T11:14:07Z and applying AMF and weights
# Regridding 2024-07-01T11:20:47Z and applying AMF and weights
# Regridding 2024-07-01T11:27:24Z and applying AMF and weights
# Regridding 2024-07-01T11:34:02Z and applying AMF and weights
# Regridding 2024-07-01T11:40:39Z and applying AMF and weights
# Regridding 2024-07-01T11:47:16Z and applying AMF and weights
# Regridding 2024-07-01T11:54:12Z and applying AMF and weights
# Regridding 2024-07-01T12:00:52Z and applying AMF and weights
# Regridding 2024-07-01T12:07:29Z and applying AMF and weights
# Regridding 2024-07-01T12:14:07Z and applying AMF and weights
# Regridding 2024-07-01T12:20:44Z and applying AMF and weights
# Regridding 2024-07-01T12:27:21Z and applying AMF and weights
# Regridding 2024-07-01T12:34:17Z and applying AMF and weights
# Regridding 2024-07-01T12:40:57Z and applying AMF and weights
# Regridding 2024-07-01T12:47:34Z and applying AMF and weights
# Regridding 2024-07-01T12:54:12Z and applying AMF and weights
# Regridding 2024-07-01T13:00:49Z and applying AMF and weights
# Regridding 2024-07-01T13:07:26Z and applying AMF and weights
# Regridding 2024-07-01T13:14:22Z and applying AMF and weights
# Regridding 2024-07-01T13:21:02Z and applying AMF and weights
# Regridding 2024-07-01T13:27:42Z and applying AMF and weights
# Regridding 2024-07-01T13:34:20Z and applying AMF and weights
# Regridding 2024-07-01T13:40:57Z and applying AMF and weights
# Regridding 2024-07-01T13:47:34Z and applying AMF and weights
# Regridding 2024-07-01T13:54:12Z and applying AMF and weights
# Regridding 2024-07-01T14:00:49Z and applying AMF and weights
# Regridding 2024-07-01T14:07:26Z and applying AMF and weights
# Regridding 2024-07-01T14:14:22Z and applying AMF and weights
# Regridding 2024-07-01T14:21:02Z and applying AMF and weights
# Regridding 2024-07-01T14:27:42Z and applying AMF and weights
# Regridding 2024-07-01T14:34:20Z and applying AMF and weights
# Regridding 2024-07-01T14:40:57Z and applying AMF and weights
# Regridding 2024-07-01T14:47:34Z and applying AMF and weights
# Regridding 2024-07-01T14:54:12Z and applying AMF and weights
# Regridding 2024-07-01T15:00:49Z and applying AMF and weights
# Regridding 2024-07-01T15:07:26Z and applying AMF and weights
# Regridding 2024-07-01T15:14:22Z and applying AMF and weights
# Regridding 2024-07-01T15:21:02Z and applying AMF and weights
# Regridding 2024-07-01T15:27:42Z and applying AMF and weights
# Regridding 2024-07-01T15:34:20Z and applying AMF and weights
# Regridding 2024-07-01T15:40:57Z and applying AMF and weights
# Regridding 2024-07-01T15:47:34Z and applying AMF and weights
# Regridding 2024-07-01T15:54:12Z and applying AMF and weights
# Regridding 2024-07-01T16:00:49Z and applying AMF and weights
# Regridding 2024-07-01T16:07:26Z and applying AMF and weights
# Regridding 2024-07-01T16:14:22Z and applying AMF and weights
# Regridding 2024-07-01T16:21:02Z and applying AMF and weights
# Regridding 2024-07-01T16:27:42Z and applying AMF and weights
# Regridding 2024-07-01T16:34:20Z and applying AMF and weights
# Regridding 2024-07-01T16:40:57Z and applying AMF and weights
# Regridding 2024-07-01T16:47:34Z and applying AMF and weights
# Regridding 2024-07-01T16:54:12Z and applying AMF and weights
# Regridding 2024-07-01T17:00:49Z and applying AMF and weights
# Regridding 2024-07-01T17:07:26Z and applying AMF and weights
# Regridding 2024-07-01T17:14:22Z and applying AMF and weights
# Regridding 2024-07-01T17:21:02Z and applying AMF and weights
# Regridding 2024-07-01T17:27:42Z and applying AMF and weights
# Regridding 2024-07-01T17:34:20Z and applying AMF and weights
# Regridding 2024-07-01T17:40:57Z and applying AMF and weights
# Regridding 2024-07-01T17:47:34Z and applying AMF and weights
# Regridding 2024-07-01T17:54:12Z and applying AMF and weights
# Regridding 2024-07-01T18:00:49Z and applying AMF and weights
# Regridding 2024-07-01T18:07:26Z and applying AMF and weights
# Regridding 2024-07-01T18:14:22Z and applying AMF and weights
# Regridding 2024-07-01T18:21:02Z and applying AMF and weights
# Regridding 2024-07-01T18:27:42Z and applying AMF and weights
# Regridding 2024-07-01T18:34:20Z and applying AMF and weights
# Regridding 2024-07-01T18:40:57Z and applying AMF and weights
# Regridding 2024-07-01T18:47:34Z and applying AMF and weights
# Regridding 2024-07-01T18:54:12Z and applying AMF and weights
# Regridding 2024-07-01T19:00:49Z and applying AMF and weights
# Regridding 2024-07-01T19:07:26Z and applying AMF and weights
# Regridding 2024-07-01T19:14:22Z and applying AMF and weights
# Regridding 2024-07-01T19:21:02Z and applying AMF and weights
# Regridding 2024-07-01T19:27:42Z and applying AMF and weights
# Regridding 2024-07-01T19:34:20Z and applying AMF and weights
# Regridding 2024-07-01T19:40:57Z and applying AMF and weights
# Regridding 2024-07-01T19:47:34Z and applying AMF and weights
# Regridding 2024-07-01T19:54:12Z and applying AMF and weights
# Regridding 2024-07-01T20:00:49Z and applying AMF and weights
# Regridding 2024-07-01T20:07:26Z and applying AMF and weights
# Regridding 2024-07-01T20:14:22Z and applying AMF and weights
# Regridding 2024-07-01T20:21:02Z and applying AMF and weights
# Regridding 2024-07-01T20:27:42Z and applying AMF and weights
# Regridding 2024-07-01T20:34:20Z and applying AMF and weights
# Regridding 2024-07-01T20:40:57Z and applying AMF and weights
# Regridding 2024-07-01T20:47:34Z and applying AMF and weights
# Regridding 2024-07-01T20:54:12Z and applying AMF and weights
# Regridding 2024-07-01T21:00:49Z and applying AMF and weights
# Regridding 2024-07-01T21:07:26Z and applying AMF and weights
# Regridding 2024-07-01T21:14:22Z and applying AMF and weights
# Regridding 2024-07-01T21:21:02Z and applying AMF and weights
# Regridding 2024-07-01T21:27:42Z and applying AMF and weights
# Regridding 2024-07-01T21:34:20Z and applying AMF and weights
# Regridding 2024-07-01T21:40:57Z and applying AMF and weights
# Regridding 2024-07-01T21:47:34Z and applying AMF and weights
# Regridding 2024-07-01T21:54:12Z and applying AMF and weights
# Regridding 2024-07-01T22:00:49Z and applying AMF and weights
# Regridding 2024-07-01T22:07:26Z and applying AMF and weights
# Regridding 2024-07-01T22:14:22Z and applying AMF and weights
# Regridding 2024-07-01T22:21:02Z and applying AMF and weights
# Regridding 2024-07-01T22:27:42Z and applying AMF and weights
# Regridding 2024-07-01T22:34:20Z and applying AMF and weights
# Regridding 2024-07-01T22:40:57Z and applying AMF and weights
# Regridding 2024-07-01T22:47:34Z and applying AMF and weights
# Regridding 2024-07-01T22:54:12Z and applying AMF and weights
# Regridding 2024-07-01T23:00:49Z and applying AMF and weights
# Regridding 2024-07-01T23:07:26Z and applying AMF and weights
# Regridding 2024-07-01T23:14:22Z and applying AMF and weights
# Regridding 2024-07-01T23:21:02Z and applying AMF and weights
# Regridding 2024-07-01T23:27:39Z and applying AMF and weights
# Regridding 2024-07-01T23:34:17Z and applying AMF and weights
# Regridding 2024-07-01T23:40:54Z and applying AMF and weights
# Regridding 2024-07-01T23:47:31Z and applying AMF and weights
# Regridding 2024-07-01T23:54:27Z and applying AMF and weights

# %%
an.paired['tempo_l2_no2_cesm_fv'].obj
# an.paired['tempo_l2_hcho_cesm_fv'].obj
# an.paired['mopitt_l3_musica'].obj
# Out:
# <xarray.Dataset> Size: 66MB
# Dimensions:                      (time: 19, y: 361, x: 571)
# Coordinates:
#   * time                         (time) datetime64[ns] 152B 2024-07-01T00:00:...
#     longitude                    (y, x) float64 2MB -127.0 -126.9 ... -70.0
#     latitude                     (y, x) float64 2MB 17.0 17.0 17.0 ... 53.0 53.0
# Dimensions without coordinates: y, x
# Data variables:
#     NO2                          (time, y, x) float64 31MB nan nan ... nan nan
#     vertical_column_troposphere  (time, y, x) float64 31MB nan nan ... nan nan
#     end_time                     (time) datetime64[ns] 152B 2024-07-01T00:34:...

# %%
an.read_control()
an.plotting()
# Out:
# Warning: vmin_plot and vmax_plot not specified for vertical_column_troposphere, so default used.
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 2.0, 'markersize': 10.0, 'label': 'tempo_l2_no2', 'fontsize': 14.4}
# Warning: no valid obs found for CNA
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 an.read_control()
# ----> 2 an.plotting()
#
# File ~/tutorials/MM_tutorial/code/MELODIES-MONET/melodies_monet/driver.py:1701, in analysis.plotting(self)
#    1698 # for pt_sfc data, convert to pandas dataframe, format, and trim
#    1699 # Query selected points if applicable
#    1700 if domain_type != 'all':
# -> 1701     p_region = select_region(p.obj, domain_type, domain_name, domain_info)
#    1702 else:
#    1703     p_region = p.obj
#
# File ~/tutorials/MM_tutorial/code/MELODIES-MONET/melodies_monet/util/region_select.py:287, in select_region(data, domain_type, domain_name, domain_info, **kwargs)
#     285     return data
#     286 if domain_type.startswith("auto-region") or (domain_type == "custom:box"):
# --> 287     data_masked = create_autoregion(data, domain_type, domain_name, domain_info)
#     288 elif domain_type.startswith("custom"):
#     289     data_masked = control_custom_mask(data, domain_type, domain_info, **kwargs)
#
# File ~/tutorials/MM_tutorial/code/MELODIES-MONET/melodies_monet/util/region_select.py:237, in create_autoregion(data, domain_type, domain_name, domain_info)
#     235     bounds = domain_info["bounds"]
#     236 else:
# --> 237     raise ValueError(
#     238         "Currently, auto-region selections without a domain query have only "
#     239         "been implemented for Giorgi and EPA regions. You asked for "
#     240         f"{domain_type!r}. If you need more capabilities, check out the custom: "
#     241         "regions capabilities. Be aware that they require regionmask."
#     242     )
#     243 if isinstance(data, pd.DataFrame):
#     244     data_all = data.loc[
#     245         (data["longitude"] >= bounds[0])
#     246         & (data["longitude"] <= bounds[1])
#     247         & (data["latitude"] >= bounds[2])
#     248         & (data["latitude"] <= bounds[3])
#     249     ]
#
# ValueError: Currently, auto-region selections without a domain query have only been implemented for Giorgi and EPA regions. You asked for 'auto-region:custom'. If you need more capabilities, check out the custom: regions capabilities. Be aware that they require regionmask.
